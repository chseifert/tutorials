# %% [markdown]
# Based on Tutorial from https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import np_utils


# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-63f34f39e9a2> in <module>()
#       1 #
# ----> 2 first_image = mnist.test.images[0]
#       3 first_image = np.array(first_image, dtype='float')
#       4 pixels = first_image.reshape((28, 28))
#       5 plt.imshow(pixels, cmap='gray')
#
# AttributeError: module 'keras.datasets.mnist' has no attribute 'test'

# %%
# flatten 28*28 images to a 784 vector for each image
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255

# %%
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(num_pixels, input_dim=num_pixels, kernel_initializer='normal', activation='relu'))
	model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))
	# Compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# build the model
model = baseline_model()
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Baseline Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
#  - 5s - loss: 0.2782 - acc: 0.9211 - val_loss: 0.1413 - val_acc: 0.9574
# Epoch 2/10
#  - 5s - loss: 0.1117 - acc: 0.9675 - val_loss: 0.0918 - val_acc: 0.9716
# Epoch 3/10
#  - 5s - loss: 0.0719 - acc: 0.9794 - val_loss: 0.0783 - val_acc: 0.9774
# Epoch 4/10
#  - 5s - loss: 0.0503 - acc: 0.9857 - val_loss: 0.0750 - val_acc: 0.9765
# Epoch 5/10
#  - 5s - loss: 0.0375 - acc: 0.9891 - val_loss: 0.0678 - val_acc: 0.9785
# Epoch 6/10
#  - 5s - loss: 0.0270 - acc: 0.9927 - val_loss: 0.0621 - val_acc: 0.9812
# Epoch 7/10
#  - 5s - loss: 0.0208 - acc: 0.9948 - val_loss: 0.0616 - val_acc: 0.9808
# Epoch 8/10
#  - 5s - loss: 0.0142 - acc: 0.9967 - val_loss: 0.0625 - val_acc: 0.9802
# Epoch 9/10
#  - 5s - loss: 0.0109 - acc: 0.9975 - val_loss: 0.0578 - val_acc: 0.9805
# Epoch 10/10
#  - 5s - loss: 0.0078 - acc: 0.9985 - val_loss: 0.0580 - val_acc: 0.9812
# Baseline Error: 1.88%

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.set_image_dim_ordering('th')

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 1, 28, 28).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 1, 28, 28).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
X_train = X_train / 255
X_test = X_test / 255
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
def baseline_DNN():
	# create model
	model = Sequential()
	model.add(Conv2D(32, (5, 5), input_shape=(1, 28, 28), activation='relu'))
	model.add(MaxPooling2D(pool_size=(2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu'))
	model.add(Dense(num_classes, activation='softmax'))
	# Compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
# build the model
model = baseline_DNN()
# Fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)
# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("CNN Error: %.2f%%" % (100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
#  - 112s - loss: 0.2315 - acc: 0.9342 - val_loss: 0.0815 - val_acc: 0.9743
# Epoch 2/10
#  - 112s - loss: 0.0738 - acc: 0.9783 - val_loss: 0.0469 - val_acc: 0.9842
# Epoch 3/10
#  - 120s - loss: 0.0530 - acc: 0.9839 - val_loss: 0.0428 - val_acc: 0.9858
# Epoch 4/10
#  - 117s - loss: 0.0401 - acc: 0.9879 - val_loss: 0.0411 - val_acc: 0.9861
# Epoch 5/10
#  - 114s - loss: 0.0336 - acc: 0.9894 - val_loss: 0.0345 - val_acc: 0.9877
# Epoch 6/10
#  - 113s - loss: 0.0275 - acc: 0.9915 - val_loss: 0.0305 - val_acc: 0.9896
# Epoch 7/10
#  - 112s - loss: 0.0233 - acc: 0.9927 - val_loss: 0.0340 - val_acc: 0.9879
# Epoch 8/10
#  - 113s - loss: 0.0202 - acc: 0.9937 - val_loss: 0.0327 - val_acc: 0.9888
# Epoch 9/10
#  - 113s - loss: 0.0171 - acc: 0.9943 - val_loss: 0.0300 - val_acc: 0.9902
# Epoch 10/10
#  - 112s - loss: 0.0140 - acc: 0.9962 - val_loss: 0.0315 - val_acc: 0.9903
# CNN Error: 0.97%

# %%
layer1 = model.get_layer(index=1)

# %%
weights = layer1.get_weights()
print(weights)
# Out:
# [array([[[[ 0.22304308,  0.10133174, -0.03144505,  0.00769589,
#           -0.2473993 , -0.04170617, -0.17481044,  0.00247429,
#           -0.14605649, -0.24931973, -0.1343395 , -0.11915264,
#           -0.04012027, -0.17259756, -0.12592623,  0.04897812,
#           -0.01052571,  0.07286554, -0.13597478, -0.11315385,
#           -0.01065364, -0.140435  ,  0.07222839, -0.02496467,
#            0.02964771, -0.03106658,  0.00953295,  0.16531895,
#            0.05319942,  0.10899932,  0.05494182,  0.05954424]],
#
#         [[ 0.17075737,  0.12165665, -0.11682913, -0.00604697,
#           -0.24593255, -0.12735404, -0.09026984, -0.03094817,
#            0.0256756 , -0.11290132, -0.23668265,  0.02938418,
#           -0.11432419, -0.13802071, -0.11335519,  0.05603295,
#            0.05175866,  0.07986863, -0.06528649, -0.15448044,
#           -0.10848895, -0.2297354 ,  0.11122803,  0.04946757,
#           -0.02892968,  0.00873273,  0.03064072, -0.02884438,
#            0.081887  ,  0.1251292 , -0.00217845,  0.13228935]],
#
#         [[-0.16109172,  0.15043084, -0.19351545,  0.10130927,
#           -0.20781933, -0.1632395 , -0.00937253,  0.02622222,
#           -0.02421505,  0.06856174, -0.24051751, -0.06822684,
#            0.0399875 , -0.03320586,  0.12811218, -0.05419083,
#           -0.04275066,  0.04993801,  0.02193606,  0.01347712,
#           -0.08207972, -0.2837573 ,  0.10164822,  0.21030629,
#            0.04891429, -0.10480931,  0.07206459, -0.16261828,
#           -0.05633322,  0.22685751,  0.01313119,  0.05944381]],
#
#         [[-0.308691  ,  0.13136797, -0.1650239 ,  0.03231609,
#           -0.25380763, -0.06962646,  0.1428417 ,  0.01869144,
#           -0.20130427,  0.14680915,  0.03880734, -0.00852471,
#           -0.11122236,  0.04804746,  0.11475886,  0.07045396,
#            0.07885548,  0.04962286,  0.095701  ,  0.07958748,
#            0.01573419, -0.0921341 ,  0.02677757,  0.16822045,
#            0.03953786,  0.09291114,  0.01653972, -0.18261057,
#           -0.17471279,  0.12887955, -0.02306755,  0.04469102]],
#
#         [[-0.3481408 ,  0.16293767,  0.24453759, -0.19734952,
#           -0.05356225,  0.03405789,  0.10094952,  0.07139737,
#           -0.00077211,  0.020482  ,  0.15257101,  0.00806535,
#           -0.17209083,  0.15305233, -0.00590104,  0.01563608,
#            0.05935916,  0.14397664,  0.01456963,  0.15840872,
#            0.03553012,  0.0245894 , -0.05815507, -0.00972714,
#           -0.001774  ,  0.06890237, -0.02127484, -0.0892112 ,
#           -0.3091783 ,  0.17813548, -0.21197627, -0.15436848]]],
#
#
#        [[[ 0.16604494, -0.02724301,  0.17116864, -0.00838802,
#           -0.40045473, -0.10484394,  0.14855836,  0.0820584 ,
#            0.0895851 , -0.27147523, -0.19791278,  0.08234905,
#           -0.13802731, -0.0588054 , -0.22778584,  0.07577623,
#           -0.03308168,  0.02439205,  0.03402886, -0.25189903,
#           -0.08741013,  0.12372993,  0.02831698, -0.1928095 ,
#            0.08568133,  0.04414513, -0.02532087, -0.26138636,
#            0.0609693 , -0.05760137, -0.03647467,  0.11871538]],
#
#         [[-0.00367663,  0.1481281 ,  0.13996182,  0.00417846,
#           -0.22916375, -0.07552826,  0.1605044 , -0.05342215,
#            0.07979149,  0.083293  , -0.12995745,  0.07360455,
#           -0.0286706 ,  0.06003636, -0.09030186,  0.0501236 ,
#           -0.03676425,  0.12665677,  0.05326435, -0.18664531,
#           -0.12130637, -0.10094482, -0.08480603, -0.12312963,
#           -0.05659713,  0.03952599,  0.11025567, -0.2698334 ,
#            0.15568683,  0.09740422,  0.01962803,  0.09595653]],
#
#         [[-0.3687216 ,  0.04966285, -0.02383473,  0.10502132,
#           -0.19892311,  0.12827714,  0.12955058, -0.188373  ,
#           -0.1336738 ,  0.1891648 , -0.17184131,  0.09200125,
#           -0.11113892,  0.11084338,  0.12290801, -0.0685182 ,
#            0.00783644,  0.12993237,  0.03965615,  0.02271282,
#           -0.12696807, -0.25114408, -0.01065061,  0.02840152,
#            0.01884164,  0.08679999,  0.05836298, -0.0812559 ,
#            0.24983333,  0.16804637,  0.02556742,  0.07648203]],
#
#         [[-0.33557785,  0.06110589, -0.25033793,  0.02484232,
#           -0.08801077,  0.13545239,  0.1038752 , -0.06149876,
#           -0.17488633,  0.0148538 ,  0.07751844,  0.01887759,
#           -0.13470568,  0.07221547,  0.03041541,  0.04152611,
#            0.00622704,  0.20061646, -0.00508337,  0.16624126,
#           -0.0579854 , -0.2330236 , -0.01460005,  0.16722438,
#            0.0789523 ,  0.07370674, -0.03020325,  0.05425059,
#            0.08913612,  0.05759647, -0.04801589, -0.1142345 ]],
#
#         [[-0.06819255,  0.05916916, -0.00627584, -0.23215514,
#           -0.19988725,  0.11941906,  0.06990025,  0.13309011,
#           -0.03043356, -0.14101714,  0.10868584,  0.10333437,
#            0.03294413, -0.03097908,  0.04027949, -0.01469023,
#            0.03822997,  0.1543154 ,  0.0363388 ,  0.07163377,
#           -0.0579375 , -0.19860181,  0.12191428,  0.0097123 ,
#            0.0273518 , -0.04477201, -0.04180362,  0.10399517,
#           -0.07088812,  0.06644487, -0.19535595, -0.268451  ]]],
#
#
#        [[[ 0.00794051, -0.22255139, -0.01587613, -0.05418017,
#           -0.32847002,  0.12394568,  0.16100338,  0.10721227,
#            0.09368348, -0.07679238, -0.25293747, -0.02409401,
#            0.00630806,  0.08762185, -0.23788275,  0.02302193,
#           -0.02703054, -0.18816912,  0.16290198, -0.18333429,
#            0.05578934,  0.14038023, -0.10607693, -0.16521464,
#           -0.02306923, -0.02171214,  0.03970181, -0.20365888,
#           -0.15560392, -0.42693105,  0.09422451,  0.08246528]],
#
#         [[-0.28181028, -0.02880891,  0.25234452,  0.07333782,
#           -0.09270221,  0.17453338,  0.13081588, -0.02025741,
#            0.05633867,  0.23150797, -0.20363565,  0.02999544,
#            0.05273831,  0.00301382, -0.07397848, -0.01822837,
#            0.07283329,  0.10775121,  0.00446342, -0.2819996 ,
#            0.10149247,  0.13527557, -0.23714049, -0.23026352,
#            0.03380426,  0.07456245,  0.07074904,  0.02990852,
#           -0.04036928, -0.2889897 ,  0.01933573,  0.09945513]],
#
#         [[-0.4297663 ,  0.04598767,  0.12660433,  0.1654798 ,
#            0.01522458,  0.14230008,  0.17711642, -0.16878197,
#            0.09929419,  0.17327583, -0.04630312, -0.08042598,
#           -0.06623822,  0.0633573 ,  0.11738124, -0.11346571,
#            0.07030261,  0.15730698,  0.02003399, -0.07985237,
#            0.13470756,  0.05913594, -0.03911069, -0.07154652,
#            0.01179101,  0.02895701,  0.07560026,  0.16465285,
#            0.15644853, -0.16377334,  0.12343696,  0.08167876]],
#
#         [[-0.09337436, -0.1051811 , -0.1591892 , -0.01689532,
#           -0.0891007 ,  0.04729972, -0.00482238,  0.04107443,
#            0.14340734, -0.08989154,  0.09893923, -0.04043447,
#            0.02455491,  0.08925332,  0.12790334,  0.0063612 ,
#            0.05843968,  0.11648907, -0.1140568 ,  0.13950245,
#            0.08150999, -0.1025778 ,  0.04200862,  0.17825446,
#           -0.00855866, -0.13211031, -0.11498368,  0.12231407,
#            0.1896578 , -0.22758515, -0.02631584, -0.2723672 ]],
#
#         [[ 0.2611312 , -0.00682212, -0.1896506 , -0.29821014,
#           -0.1318319 , -0.05702616, -0.19533221,  0.01647857,
#            0.05186843, -0.110211  ,  0.0767941 , -0.00354068,
#            0.1020122 , -0.10864166,  0.0313224 , -0.00265031,
#           -0.04324222, -0.00232811,  0.01107859,  0.13822272,
#            0.06157864, -0.2522503 ,  0.1615305 ,  0.14221652,
#           -0.02450085, -0.00570721, -0.10978849,  0.09678113,
#            0.06928084, -0.2867331 , -0.1879492 , -0.24155971]]],
#
#
#        [[[-0.10247077, -0.28541434, -0.15727687, -0.1735322 ,
#            0.06689158,  0.16753387, -0.18846661,  0.06451629,
#            0.00915086,  0.03452545, -0.19061843, -0.04068073,
#            0.05456008,  0.03629847, -0.14945482,  0.00373441,
#           -0.00251351, -0.40118328, -0.06967542,  0.01914351,
#            0.12682238,  0.12169893, -0.21032707,  0.03371591,
#            0.06842186, -0.05307407,  0.08923188,  0.08681594,
#           -0.08449689, -0.13320108, -0.01477639,  0.15413919]],
#
#         [[-0.46263334, -0.19768749,  0.09786905,  0.10263373,
#            0.13620026,  0.06801154, -0.1138479 ,  0.06019467,
#           -0.04751047,  0.1932613 , -0.13229902, -0.02597458,
#            0.02578988,  0.07314883, -0.03534737,  0.01298126,
#            0.00863224, -0.20444271, -0.00704456, -0.27466705,
#            0.11043471,  0.22656676, -0.06959844, -0.3477432 ,
#           -0.00893721, -0.01420024,  0.12079109,  0.16655292,
#           -0.18730374, -0.21260244,  0.09706721,  0.05229545]],
#
#         [[-0.14919473, -0.22595908,  0.10031307,  0.18493602,
#            0.16078252,  0.05415753, -0.20280291, -0.02901451,
#            0.0288326 , -0.02210317,  0.03196961, -0.00215516,
#            0.09054826,  0.07888381,  0.0504888 , -0.06702653,
#            0.07433715, -0.1546695 , -0.06493519, -0.04206253,
#            0.07415072,  0.23462051,  0.11412659, -0.2598807 ,
#            0.04182301, -0.0911812 ,  0.01820743,  0.04615234,
#           -0.12137859, -0.33763793,  0.15207528, -0.11225128]],
#
#         [[ 0.13163432, -0.15629902,  0.13087851, -0.00783641,
#            0.08078399, -0.02823065, -0.3032189 ,  0.06859685,
#            0.11748495, -0.31095907,  0.02665504, -0.08831819,
#            0.08433863,  0.01675191,  0.13420047,  0.06628484,
#           -0.03759399, -0.10877642,  0.05146575, -0.01522538,
#           -0.01741352,  0.06603662,  0.08804002,  0.03508251,
#            0.01433054,  0.08926661, -0.09152646,  0.05053554,
#            0.11158954, -0.20597365,  0.09464131, -0.35647056]],
#
#         [[ 0.25631896, -0.03905181, -0.13095757, -0.2567894 ,
#            0.07064034,  0.00566439, -0.2147783 , -0.00596616,
#            0.08165094, -0.13719411,  0.13906725,  0.04907958,
#            0.04960123, -0.2132217 , -0.03192224,  0.06329133,
#           -0.0235704 , -0.2990744 ,  0.02730502,  0.09666201,
#            0.0822964 , -0.1659185 ,  0.06964208,  0.1483307 ,
#            0.05868042,  0.09108137, -0.10290137, -0.03766915,
#            0.11176603, -0.0710346 , -0.04062683,  0.09863471]]],
#
#
#        [[[-0.2456646 , -0.08228633, -0.25544158, -0.18183106,
#            0.03145043, -0.19508985, -0.26965588,  0.00253069,
#           -0.06432055,  0.04854637, -0.27930665, -0.00198047,
#            0.0941955 ,  0.1523837 , -0.12819143, -0.06077908,
#            0.05872439, -0.25530672, -0.09633076, -0.01947876,
#           -0.01947793, -0.04571361, -0.09153638,  0.37741742,
#            0.06530999,  0.05682043,  0.10711884,  0.11879897,
#           -0.08078217, -0.09225575, -0.02275775,  0.05286816]],
#
#         [[-0.22086053, -0.08605698, -0.00724497,  0.1525484 ,
#            0.07126597, -0.15647252, -0.30853692,  0.08983546,
#           -0.04050658,  0.05502737, -0.06676038,  0.08033351,
#            0.11474799, -0.03938982, -0.04112634, -0.03863954,
#            0.08607135, -0.35541308,  0.03087566, -0.26216802,
#           -0.05586712, -0.00545754,  0.13892429, -0.09849616,
#           -0.03384717,  0.02773887, -0.08623491,  0.08833841,
#           -0.03120248, -0.03118705, -0.02954067, -0.10913255]],
#
#         [[-0.11971617, -0.06809911,  0.06270641,  0.20537443,
#            0.11709705, -0.21935795, -0.23342268,  0.11824647,
#           -0.10324593, -0.17424363, -0.01430344,  0.08386441,
#            0.05062228, -0.03252835,  0.0367875 ,  0.10083245,
#           -0.00843996, -0.33230275,  0.02636383, -0.16516192,
#           -0.08645336,  0.12982269,  0.09591324, -0.27779573,
#            0.03549185,  0.08770204,  0.03200998, -0.00478005,
#           -0.16538928,  0.00771014,  0.08398037, -0.23948376]],
#
#         [[ 0.09079108,  0.03704515,  0.11079802, -0.09036737,
#            0.18573606, -0.16149336,  0.00871755, -0.09073889,
#           -0.04419537, -0.12141979,  0.1000284 , -0.03750369,
#            0.07887178,  0.03023184,  0.13823535,  0.07773609,
#            0.02994661, -0.36299357,  0.1362455 , -0.0440043 ,
#            0.03615607,  0.19379525,  0.05985431, -0.19984144,
#            0.08039364, -0.05201599, -0.11219314, -0.14080456,
#            0.03350246,  0.07570916,  0.1502023 , -0.20540178]],
#
#         [[ 0.13878955, -0.0665457 ,  0.07213251, -0.2482771 ,
#            0.21853043, -0.10620337,  0.10024896, -0.2185561 ,
#            0.00395193,  0.10889474,  0.03814356,  0.09830455,
#            0.00669637, -0.1699416 ,  0.01184095, -0.05053258,
#           -0.09633606, -0.21740073, -0.12439833,  0.05454868,
#           -0.04466305, -0.00418404, -0.07305801,  0.01398788,
#           -0.0201712 , -0.01620866, -0.08329245, -0.13602127,
#           -0.03688175,  0.00835484, -0.01676405,  0.15296532]]]],
#       dtype=float32), array([-1.45597616e-04, -8.76916293e-03, -4.28042337e-02, -4.98342142e-02,
#        -1.02188615e-02, -3.99940973e-03,  8.84672481e-05, -8.68357718e-02,
#        -7.66358152e-02, -5.67297377e-02, -3.26204337e-02, -1.08138219e-01,
#        -2.46305875e-02, -1.52961820e-01, -1.17206901e-01, -9.91853923e-02,
#        -1.50214136e-01, -3.98353208e-03, -6.17873482e-02, -2.63028517e-02,
#        -6.60747066e-02, -1.87777448e-02, -1.60048634e-01, -7.25286128e-03,
#        -1.44147113e-01, -1.02023832e-01, -1.34569153e-01, -2.13197414e-02,
#        -1.08680606e-01, -7.87420757e-03, -1.53046653e-01, -1.18709058e-02],
#       dtype=float32)]
